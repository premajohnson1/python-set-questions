# %%
#1.What is wrong with the following function definition, and how do you fix it?


def say_hello(name)
    print("Hello, " + name)


: missing; syntax error

# %%
#2.What error will occur in the following code, and how do you fix it?


age = 25
print("I am " + age + " years old")

type error; cant concatenate int with string

# %%
#3.Question:
What is the issue with the following code?

def greet():
    message = "Hello"
print(message)

NameError: name message is not defined

# %%
#4.What error will occur in the following code, and how do you fix it?

def add(a, b):
    return a + b

print(add(5))

function expects 2 arguments

# %%
#5.What is wrong with this code?

def is_even(n):
    if n % 2 == 1:
        return True
    else:
        return False

logic is wromg; if n%2==0 for even

# %%
#6.What happens when you run this code?

num = int("10a")
print(num)

10a is not integer; value error

# %%
num = int("10a")
print(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 num = int("10a")
#       2 print(num)
#
# ValueError: invalid literal for int() with base 10: '10a'

# %%
#7.What will happen when you run the following code?


numbers = [1, 2, 3, 4]
numbers.sort().reverse()
print(numbers)

# %%
numbers = [1, 2, 3, 4]
numbers.sort().reverse()
print(numbers)


numbers.sort() gives none value; we cant reverse the none value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 numbers = [1, 2, 3, 4]
# ----> 2 numbers.sort().reverse()
#       3 print(numbers)
#
# AttributeError: 'NoneType' object has no attribute 'reverse'

# %%
#8.What is the issue with this code?


numbers = [1, 2, 3]
numbers = numbers.append(4)
print(numbers)

# %%
numbers = [1, 2, 3]
numbers = numbers.append(4)
print(numbers)
# Out:
# None

# %%
#9.What will happen when you run the following code?


count = 10

def increment():
    count += 1
    print(count)

increment()

count is global variable; to print count it should be local variable; so 
def increment():
    global count
    count += 1
    print(count)
# Out:
#   Cell In[1], line 12
#     count is global variable; to print count it should be local variable; so
#              ^
# SyntaxError: invalid syntax

# %%
count = 10

def increment():
    global count
    count += 1
    print(count)

increment()
# Out:
# 11

# %%
#10.What error will occur in the following code?

text = "Python"
print(text[10])
