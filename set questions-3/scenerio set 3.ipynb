# %%
1. A user is required to enter a valid number in a form, but users sometimes input invalid data.
 Write logic to repeatedly prompt the user until they enter a valid integer.

# %%
while True:
    try:
        num=int(input("enter the value"))
        print(num)
        break
    except:
        print("enter a valid integer")
# Out:
# enter the value prema
# enter a valid integer
# enter the value gshfhs
# enter a valid integer
# enter the value cjxzvxm
# enter a valid integer
# enter the value 2
# 2

# %%
2.Scenario: A data analysis tool processes a list of numbers and needs to identify the most frequently occurring value.

# %%
numbers=[1, 2, 2, 3, 2, 4, 4,4, 3]
highestCount=0
frequent=[]
for i in numbers:
    count=numbers.count(i)

    if count>highestCount:
        highestCount=count

for i in numbers:
    if numbers.count(i)==highestCount and i not in frequent:
        frequent.append(i)
print(frequent)
# Out:
# [2, 4]

# %%
3.Scenario: A text-processing application needs to compare words and check if they are anagrams (contain the same letters in a different order).
 Write logic to determine whether two given strings are anagrams. eg: listen, silent

# %%
word1=input("enter the word1")
word2=input("enter the word2")

if sorted(word1)==sorted(word2):
    print("anagrams")
else:
    print("not anagrams")
# Out:
# enter the word1 race
# enter the word2 care
# anagrams

# %%
4.Scenario: A speech analysis program needs to count the number of vowel sounds in a given input.
 Write logic to count the number of vowels in a given string.

# %%
word=input("enter the word")
count=0
vowel=['a','e','i','o','u']
for i in word:
    if i in vowel:
        count +=1
print(count)
# Out:
# enter the word prema
# 2

# %%
Scenario: A text-editing software includes a feature to reverse the order of words in a sentence for stylistic effects.
 Write logic to reverse the order of words in a sentence while keeping the words themselves intact.

# %%
sentence=input("enter the sentence")
words=sentence.split()
words.reverse()
rev=" ".join(words)
print(rev)
# Out:
# enter the sentence i am prema
# prema am i

# %%
6.Scenario: A missing number is detected in a sequence of values stored in a database.
 Write logic to find the missing number in a list containing n-1 numbers from 1 to n.

# %%
database=[1,2,3,4,6]
number=int(input("enter the value"))
sum=0
databaseSum=0
for i in range(1,number+1):
    sum=i+sum
for i in database:
    databaseSum=databaseSum+i
    
print(sum-databaseSum)
# Out:
# enter the value 6
# 5

# %%
    7.Scenario: An ATM machine processes withdrawal requests and needs to ensure that users cannot withdraw more than their account balance.
 Write logic to allow a withdrawal only if the balance is sufficient.

# %%
amount=int(input("enter the amount to withdraw"))
balance=int(input("enter the balance"))
if amount<=balance:
    print("balance is sufficient")
else:
    print("balance is insufficient")
# Out:
# enter the amount to withdraw 2000
# enter the balance 1000
# balance is insufficient

# %%
8.Scenario: A system needs to verify whether a given dataset contains duplicate entries.
 Write logic to check whether a given list contains duplicate values.

# %%
numbers=[1,2,2,4,4,5]
mostFrequent=numbers[0]
highestCount=0
for i in numbers:
    count=numbers.count(i)
    
    
    if(count>1):
        print("contains duplicate")
        break
else:
    print("no duplicates")
# Out:
# contains duplicate

# %%
9.Scenario: A digital calculator includes a feature to sum the digits of a number for verification purposes.
 Write logic to calculate the sum of all digits in a given integer.

# %%
number=int(input("enter the value"))
sum=0
digit=0

while number>0:
    digit=number%10
    sum=sum+digit
    number=number//10
print(sum)
# Out:
# enter the value 123
# 6

# %%
10.Scenario: A language-learning app wants to verify whether a given sentence is a pangram (contains every letter of the alphabet at least once).
 Write logic to check if a given sentence is a pangram.

# %%
sentence=input("enter the sentence")
sentence=sentence.lower()
letters=set()

for i in sentence:
    if i.isalpha():
        letters.add(i)
if len(letters)==26:
    print("pangram")
else:
    print("not pangram")
# Out:
# enter the sentence The quick brown fox jumps over the lazy
# not pangram
