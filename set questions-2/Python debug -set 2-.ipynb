# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))

name error; math should be same

# %%
#2.Find the error in the following Python code:
def my_function():
    global x
    x += 5
    print(x)

x = 10
my_function()
# Out:
# 15

# %%
#3.x = 5
if x = 10:
    print("x is 10")
error: it should be x==10; for comparison

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())
 this will  return none; for print sorted values use: print(numbers)

# %%
#5.
def square(n):
    n * n

print(square(4))
 function didnt return any values

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5

ans: my_tuple=(1,5, 3) to get the output

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))

%(name,age) this is correct

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")


if a==b is correct

# %%
#9.
for i in range(5, 1):
    print(i)


range(5,1,-1)
range(1,5)

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])

error: name error; keys should be the string; so "name" is correct
